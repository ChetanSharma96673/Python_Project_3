# %%
#EDA on Sales Data

# %%
#Importing the modules

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
#Importing the dataset

# %%
df = pd.read_csv(r"C:\Users\Admin\Downloads\archive (5)\Sales Data.csv")

# %%
df
# Out:
#         Unnamed: 0  Order ID                 Product  Quantity Ordered  \
# 0                0    295665      Macbook Pro Laptop                 1
# 1                1    295666      LG Washing Machine                 1
# 2                2    295667    USB-C Charging Cable                 1
# 3                3    295668        27in FHD Monitor                 1
# 4                4    295669    USB-C Charging Cable                 1
# ...            ...       ...                     ...               ...
# 185945       13617    222905  AAA Batteries (4-pack)                 1
# 185946       13618    222906        27in FHD Monitor                 1
# 185947       13619    222907    USB-C Charging Cable                 1
# 185948       13620    222908    USB-C Charging Cable                 1
# 185949       13621    222909  AAA Batteries (4-pack)                 1
#
#         Price Each           Order Date  \
# 0          1700.00  2019-12-30 00:01:00
# ...

# %%
#Info about the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        185950 non-null  int64
#  1   Order ID          185950 non-null  int64
#  2   Product           185950 non-null  object
#  3   Quantity Ordered  185950 non-null  int64
#  4   Price Each        185950 non-null  float64
#  5   Order Date        185950 non-null  object
#  6   Purchase Address  185950 non-null  object
#  7   Month             185950 non-null  int64
#  8   Sales             185950 non-null  float64
#  9   City              185950 non-null  object
#  10  Hour              185950 non-null  int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 15.6+ MB

# %%
#Dropping the unwanted data

# %%
df.drop(columns = 'Unnamed: 0',inplace = True)

# %%
df
# Out:
#         Order ID                 Product  Quantity Ordered  Price Each  \
# 0         295665      Macbook Pro Laptop                 1     1700.00
# 1         295666      LG Washing Machine                 1      600.00
# 2         295667    USB-C Charging Cable                 1       11.95
# 3         295668        27in FHD Monitor                 1      149.99
# 4         295669    USB-C Charging Cable                 1       11.95
# ...          ...                     ...               ...         ...
# 185945    222905  AAA Batteries (4-pack)                 1        2.99
# 185946    222906        27in FHD Monitor                 1      149.99
# 185947    222907    USB-C Charging Cable                 1       11.95
# 185948    222908    USB-C Charging Cable                 1       11.95
# 185949    222909  AAA Batteries (4-pack)                 1        2.99
#
#                  Order Date                        Purchase Address  Month  \
# ...

# %%
#Describing the dataset

# %%
df.describe()
# Out:
#             Order ID  Quantity Ordered     Price Each          Month  \
# count  185950.000000     185950.000000  185950.000000  185950.000000
# mean   230417.569379          1.124383     184.399735       7.059140
# std     51512.737110          0.442793     332.731330       3.502996
# min    141234.000000          1.000000       2.990000       1.000000
# 25%    185831.250000          1.000000      11.950000       4.000000
# 50%    230367.500000          1.000000      14.950000       7.000000
# 75%    275035.750000          1.000000     150.000000      10.000000
# max    319670.000000          9.000000    1700.000000      12.000000
#
#                Sales           Hour
# count  185950.000000  185950.000000
# mean      185.490917      14.413305
# std       332.919771       5.423416
# min         2.990000       0.000000
# 25%        11.950000      11.000000
# 50%        14.950000      15.000000
# 75%       150.000000      19.000000
# max      3400.000000      23.000000

# %%
df.head(10)
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    295665          Macbook Pro Laptop                 1     1700.00
# 1    295666          LG Washing Machine                 1      600.00
# 2    295667        USB-C Charging Cable                 1       11.95
# 3    295668            27in FHD Monitor                 1      149.99
# 4    295669        USB-C Charging Cable                 1       11.95
# 5    295670       AA Batteries (4-pack)                 1        3.84
# 6    295671        USB-C Charging Cable                 1       11.95
# 7    295672        USB-C Charging Cable                 2       11.95
# 8    295673  Bose SoundSport Headphones                 1       99.99
# 9    295674      AAA Batteries (4-pack)                 4        2.99
#
#             Order Date                           Purchase Address  Month  \
# 0  2019-12-30 00:01:00     136 Church St, New York City, NY 10001     12
# ...

# %%
df.tail(10)
# Out:
#         Order ID                   Product  Quantity Ordered  Price Each  \
# 185940    222901    AAA Batteries (4-pack)                 1        2.99
# 185941    222902  Lightning Charging Cable                 1       14.95
# 185942    222903                    iPhone                 1      700.00
# 185943    222903  Lightning Charging Cable                 1       14.95
# 185944    222904        Macbook Pro Laptop                 1     1700.00
# 185945    222905    AAA Batteries (4-pack)                 1        2.99
# 185946    222906          27in FHD Monitor                 1      149.99
# 185947    222907      USB-C Charging Cable                 1       11.95
# 185948    222908      USB-C Charging Cable                 1       11.95
# 185949    222909    AAA Batteries (4-pack)                 1        2.99
#
#                  Order Date                         Purchase Address  Month  \
# 185940  2019-06-11 04:00:00          891 South St, Atlanta, GA 30301      6
# ...

# %%
#Handling the null values

# %%
df.isnull()
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 0          False    False             False       False       False
# 1          False    False             False       False       False
# 2          False    False             False       False       False
# 3          False    False             False       False       False
# 4          False    False             False       False       False
# ...          ...      ...               ...         ...         ...
# 185945     False    False             False       False       False
# 185946     False    False             False       False       False
# 185947     False    False             False       False       False
# 185948     False    False             False       False       False
# 185949     False    False             False       False       False
#
#         Purchase Address  Month  Sales   City   Hour
# 0                  False  False  False  False  False
# ...

# %%
df.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# Month               0
# Sales               0
# City                0
# Hour                0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
#Handling the datatypes of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  int64
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  int64
#  7   Sales             185950 non-null  float64
#  8   City              185950 non-null  object
#  9   Hour              185950 non-null  int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 14.2+ MB

# %%
df['Month'] = df['Month'].astype('category')
df['City'] = df['City'].astype('category')

# %%
#All the datatypes are in correct format

# %%
#Visualizations

# %%
#Product

# %%
#Unique Products

# %%
a = list(df['Product'].unique())

# %%
print("The Unique Products are: \n",a)
# Out:
# The Unique Products are:
#  ['Macbook Pro Laptop', 'LG Washing Machine', 'USB-C Charging Cable', '27in FHD Monitor', 'AA Batteries (4-pack)', 'Bose SoundSport Headphones', 'AAA Batteries (4-pack)', 'ThinkPad Laptop', 'Lightning Charging Cable', 'Google Phone', 'Wired Headphones', 'Apple Airpods Headphones', 'Vareebadd Phone', 'iPhone', '20in Monitor', '34in Ultrawide Monitor', 'Flatscreen TV', '27in 4K Gaming Monitor', 'LG Dryer']

# %%
#Value Counts of each product

# %%
df.value_counts('Product')
# Out:
# Product
# USB-C Charging Cable          21903
# Lightning Charging Cable      21658
# AAA Batteries (4-pack)        20641
# AA Batteries (4-pack)         20577
# Wired Headphones              18882
# Apple Airpods Headphones      15549
# Bose SoundSport Headphones    13325
# 27in FHD Monitor               7507
# iPhone                         6842
# 27in 4K Gaming Monitor         6230
# 34in Ultrawide Monitor         6181
# Google Phone                   5525
# Flatscreen TV                  4800
# Macbook Pro Laptop             4724
# ThinkPad Laptop                4128
# 20in Monitor                   4101
# Vareebadd Phone                2065
# LG Washing Machine              666
# LG Dryer                        646
# dtype: int64

# %%
sns.set(rc={'figure.figsize':(45,10)})
a = sns.countplot('Product',data = df)
a.set_xlabel('Product')
a.set_ylabel('Total')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Total')

# %%
#Products VS Quantity Orderd

# %%
total_product_sold = df.groupby('Product', as_index = False)['Quantity Ordered'].sum().sort_values(by='Quantity Ordered',ascending = False)
total_product_sold
# Out:
#                        Product  Quantity Ordered
# 5       AAA Batteries (4-pack)             31017
# 4        AA Batteries (4-pack)             27635
# 15        USB-C Charging Cable             23975
# 12    Lightning Charging Cable             23217
# 17            Wired Headphones             20557
# 6     Apple Airpods Headphones             15661
# 7   Bose SoundSport Headphones             13457
# 2             27in FHD Monitor              7550
# 18                      iPhone              6849
# 1       27in 4K Gaming Monitor              6244
# 3       34in Ultrawide Monitor              6199
# 9                 Google Phone              5532
# 8                Flatscreen TV              4819
# 13          Macbook Pro Laptop              4728
# 14             ThinkPad Laptop              4130
# 0                 20in Monitor              4129
# 16             Vareebadd Phone              2068
# 11          LG Washing Machine               666
# ...

# %%
sns.set(rc={'figure.figsize':(45,10)})
a = sns.countplot('Product',data = df)
a.set_xlabel('Product')
a.set_ylabel('Total')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Total')

# %%
#Products VS Sales

# %%
total_product_sales = df.groupby('Product', as_index = False)['Sales'].sum().sort_values(by = 'Sales', ascending = False)
total_product_sales
# Out:
#                        Product       Sales
# 13          Macbook Pro Laptop  8037600.00
# 18                      iPhone  4794300.00
# 14             ThinkPad Laptop  4129958.70
# 9                 Google Phone  3319200.00
# 1       27in 4K Gaming Monitor  2435097.56
# 3       34in Ultrawide Monitor  2355558.01
# 6     Apple Airpods Headphones  2349150.00
# 8                Flatscreen TV  1445700.00
# 7   Bose SoundSport Headphones  1345565.43
# 2             27in FHD Monitor  1132424.50
# 16             Vareebadd Phone   827200.00
# 0                 20in Monitor   454148.71
# 11          LG Washing Machine   399600.00
# 10                    LG Dryer   387600.00
# 12    Lightning Charging Cable   347094.15
# 15        USB-C Charging Cable   286501.25
# 17            Wired Headphones   246478.43
# 4        AA Batteries (4-pack)   106118.40
# 5       AAA Batteries (4-pack)    92740.83

# %%
plt.figure(figsize=(45, 10))
sns.barplot(x = 'Product',y = 'Sales',data = df)
# Out:
# <AxesSubplot:xlabel='Product', ylabel='Sales'>

# %%
#Top 10 products on the basis of quantity

# %%
top_10_products_quantity = df.groupby('Product',as_index=False)['Quantity Ordered'].sum().nlargest(10,'Quantity Ordered').sort_values(by = 'Quantity Ordered',ascending = False)

# %%
top_10_products_quantity
# Out:
#                        Product  Quantity Ordered
# 5       AAA Batteries (4-pack)             31017
# 4        AA Batteries (4-pack)             27635
# 15        USB-C Charging Cable             23975
# 12    Lightning Charging Cable             23217
# 17            Wired Headphones             20557
# 6     Apple Airpods Headphones             15661
# 7   Bose SoundSport Headphones             13457
# 2             27in FHD Monitor              7550
# 18                      iPhone              6849
# 1       27in 4K Gaming Monitor              6244

# %%
#Bottom 10 products on the basis of quantity

# %%
bottom_10_products_quantity = df.groupby('Product',as_index=False)['Quantity Ordered'].sum().nsmallest(10,'Quantity Ordered').sort_values(by = 'Quantity Ordered',ascending = False)

# %%
bottom_10_products_quantity
# Out:
#                    Product  Quantity Ordered
# 1   27in 4K Gaming Monitor              6244
# 3   34in Ultrawide Monitor              6199
# 9             Google Phone              5532
# 8            Flatscreen TV              4819
# 13      Macbook Pro Laptop              4728
# 14         ThinkPad Laptop              4130
# 0             20in Monitor              4129
# 16         Vareebadd Phone              2068
# 11      LG Washing Machine               666
# 10                LG Dryer               646

# %%
#Top 10 products on the basis of Sales

# %%
top_10_products_sales = df.groupby('Product',as_index=False)['Sales'].sum().nlargest(10,'Sales').sort_values('Sales',ascending = False)

# %%
top_10_products_sales
# Out:
#                        Product       Sales
# 13          Macbook Pro Laptop  8037600.00
# 18                      iPhone  4794300.00
# 14             ThinkPad Laptop  4129958.70
# 9                 Google Phone  3319200.00
# 1       27in 4K Gaming Monitor  2435097.56
# 3       34in Ultrawide Monitor  2355558.01
# 6     Apple Airpods Headphones  2349150.00
# 8                Flatscreen TV  1445700.00
# 7   Bose SoundSport Headphones  1345565.43
# 2             27in FHD Monitor  1132424.50

# %%
bottom_10_products_sales = df.groupby('Product',as_index=False)['Sales'].sum().nsmallest(10,'Sales').sort_values('Sales',ascending = False)

# %%
bottom_10_products_sales
# Out:
#                      Product       Sales
# 2           27in FHD Monitor  1132424.50
# 16           Vareebadd Phone   827200.00
# 0               20in Monitor   454148.71
# 11        LG Washing Machine   399600.00
# 10                  LG Dryer   387600.00
# 12  Lightning Charging Cable   347094.15
# 15      USB-C Charging Cable   286501.25
# 17          Wired Headphones   246478.43
# 4      AA Batteries (4-pack)   106118.40
# 5     AAA Batteries (4-pack)    92740.83

# %%
#Products VS Month

# %%
df['Month'].value_counts().sort_values(ascending = True)
# Out:
# 1      9709
# 9     11621
# 8     11961
# 2     11975
# 6     13554
# 7     14293
# 3     15153
# 5     16566
# 11    17573
# 4     18279
# 10    20282
# 12    24984
# Name: Month, dtype: int64

# %%
pd.crosstab(df['Month'],df['Quantity Ordered'])
# Out:
# Quantity Ordered      1     2    3    4   5   6  7  8  9
# Month
# 1                  8819   672  160   39  13   3  3  0  0
# 2                 10853   859  194   54  11   3  1  0  0
# 3                 13778  1032  250   61  24   7  1  0  0
# 4                 16548  1328  299   72  24   7  1  0  0
# 5                 14990  1219  234   85  32   5  1  0  0
# 6                 12232  1036  221   47  13   4  0  0  1
# 7                 12975  1018  209   50  23  12  3  1  2
# 8                 10849   858  173   56  16   4  4  1  0
# 9                 10483   871  199   55  11   2  0  0  0
# 10                18469  1388  294   98  21   7  3  2  0
# 11                15919  1250  291   80  18  10  4  1  0
# 12                22637  1793  396  109  30  16  3  0  0

# %%
month_quantity = df.groupby('Month',as_index=False)['Quantity Ordered'].sum().sort_values('Quantity Ordered',ascending = False)

# %%
month_quantity
# Out:
#    Month  Quantity Ordered
# 11    12             28114
# 9     10             22703
# 3      4             20558
# 10    11             19798
# 4      5             18667
# 2      3             17005
# 6      7             16072
# 5      6             15253
# 1      2             13449
# 7      8             13448
# 8      9             13109
# 0      1             10903

# %%
#Sales VS Month

# %%
month_sales = df.groupby('Month',as_index=False)['Sales'].sum().sort_values('Sales',ascending = False)

# %%
month_sales
# Out:
#    Month         Sales
# 11    12  4.613443e+06
# 9     10  3.736727e+06
# 3      4  3.390670e+06
# 10    11  3.199603e+06
# 4      5  3.152607e+06
# 2      3  2.807100e+06
# 6      7  2.647776e+06
# 5      6  2.577802e+06
# 7      8  2.244468e+06
# 1      2  2.202022e+06
# 8      9  2.097560e+06
# 0      1  1.822257e+06

# %%
#Products VS Hours

# %%
product_hours = df.groupby('Hour',as_index=False)['Quantity Ordered'].sum().sort_values('Quantity Ordered',ascending = False)

# %%
product_hours
# Out:
#     Hour  Quantity Ordered
# 19    19             14470
# 12    12             14202
# 11    11             14005
# 18    18             13802
# 20    20             13768
# 13    13             13685
# 14    14             12362
# 10    10             12308
# 21    21             12244
# 17    17             12229
# 16    16             11662
# 15    15             11391
# 22    22              9899
# 9      9              9816
# 23    23              7065
# 8      8              7002
# 7      7              4556
# 0      0              4428
# 6      6              2810
# 1      1              2619
# 5      5              1493
# 2      2              1398
# 4      4               937
# 3      3               928

# %%
#Sales VS Hours

# %%
sales_hours = df.groupby('Hour',as_index=False)['Sales'].sum().sort_values('Sales',ascending = False)

# %%
sales_hours
# Out:
#     Hour       Sales
# 19    19  2412938.54
# 12    12  2316821.34
# 11    11  2300610.24
# 20    20  2281716.24
# 18    18  2219348.30
# 13    13  2155389.80
# 17    17  2129361.61
# 14    14  2083672.73
# 21    21  2042000.86
# 10    10  1944286.77
# 15    15  1941549.60
# 16    16  1904601.31
# 9      9  1639030.58
# 22    22  1607549.21
# 8      8  1192348.97
# 23    23  1179304.44
# 7      7   744854.12
# 0      0   713721.27
# 1      1   460866.88
# 6      6   448113.00
# 2      2   234851.44
# 5      5   230679.82
# 4      4   162661.01
# 3      3   145757.89

# %%
#Top 5 and Bottom 5 Sales cities

# %%
top_5_sales_cities = df.groupby('City',as_index=False)['Sales'].sum().nlargest(5,'Sales').sort_values('Sales',ascending = True)

# %%
top_5_sales_cities
# Out:
#              City         Sales
# 0         Atlanta  2.795499e+06
# 2          Boston  3.661642e+06
# 5   New York City  4.664317e+06
# 4     Los Angeles  5.452571e+06
# 7   San Francisco  8.262204e+06

# %%
bottom_5_sales_cities = df.groupby('City',as_index=False)['Sales'].sum().nsmallest(5,'Sales').sort_values('Sales',ascending = True)

# %%
bottom_5_sales_cities
# Out:
#         City       Sales
# 1     Austin  1819581.75
# 6   Portland  2320490.61
# 8    Seattle  2747755.48
# 3     Dallas  2767975.40
# 0    Atlanta  2795498.58

# %%
#Price VS Quantity Ordered

# %%
pd.crosstab(df['Price Each'],df['Quantity Ordered'])
# Out:
# Quantity Ordered      1     2     3    4    5   6   7  8  9
# Price Each
# 2.99              13726  4630  1502  524  166  63  22  5  3
# 3.84              15333  3874  1033  250   69  16   2  0  0
# 11.95             20019  1713   157   12    1   1   0  0  0
# 11.99             17361  1380   128   13    0   0   0  0  0
# 14.95             20210  1344    97    7    0   0   0  0  0
# 99.99             13195   128     2    0    0   0   0  0  0
# 109.99             4073    28     0    0    0   0   0  0  0
# 149.99             7464    43     0    0    0   0   0  0  0
# 150.00            15438   110     1    0    0   0   0  0  0
# 300.00             4781    19     0    0    0   0   0  0  0
# 379.99             6163    18     0    0    0   0   0  0  0
# 389.99             6216    14     0    0    0   0   0  0  0
# 400.00             2062     3     0    0    0   0   0  0  0
# 600.00             6830     7     0    0    0   0   0  0  0
# ...

# %%
#Customer VS Sales

# %%
#Top 10 Customer by Sales

# %%
df.groupby('Order ID',as_index=False)['Sales'].sum().nlargest(10,'Sales').sort_values('Sales', ascending = False)
# Out:
#         Order ID    Sales
# 39835     181069  3779.99
# 40310     181544  3400.00
# 59294     200528  3400.00
# 60978     202212  3400.00
# 69058     210292  3400.00
# 102494    243728  3400.00
# 114084    255318  3400.00
# 35948     177182  2699.99
# 46853     188087  2699.99
# 47973     189207  2699.99

# %%
#Bottom 10 Customer by Sales

# %%
df.groupby('Order ID',as_index=False)['Sales'].sum().nsmallest(10,'Sales').sort_values('Sales', ascending = False)
# Out:
#     Order ID  Sales
# 5     141239   2.99
# 20    141254   2.99
# 26    141260   2.99
# 28    141262   2.99
# 38    141272   2.99
# 46    141280   2.99
# 58    141292   2.99
# 65    141299   2.99
# 73    141307   2.99
# 76    141310   2.99
